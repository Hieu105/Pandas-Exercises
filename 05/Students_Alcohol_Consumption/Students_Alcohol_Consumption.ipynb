# %% [markdown]
# # Student Alcohol Consumption
#
# Click the button below to run this notebook directly on Google Colab:
#
# [<img src="https://colab.research.google.com/assets/colab-badge.svg" align="left">](https://colab.research.google.com/github)

# %% [markdown]
# ### Introduction:
#
# This time you will download a dataset from the UCI.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/thieu1995/csv-files/main/data/pandas/student-mat.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called df.

# %%
url = 'https://raw.githubusercontent.com/thieu1995/csv-files/main/data/pandas/student-mat.csv'
df = pd.read_csv(url)
df.head()

# %% [markdown]
# ### Step 4. For the purpose of this exercise slice the dataframe from 'school' until the 'guardian' column

# %%
stud_alco = df.loc[:, 'school':'guardian']
stud_alco.head()

# %% [markdown]
# ### Step 5. Create a lambda function that will capitalize strings.

# %%
capitalizer = lambda x: x.capitalize()

# %% [markdown]
# ### Step 6. Capitalize both Mjob and Fjob

# %%
stud_alco['Mjob'] = stud_alco['Mjob'].apply(capitalizer)
stud_alco['Fjob'] = stud_alco['Fjob'].apply(capitalizer)
stud_alco.head()

# %% [markdown]
# ### Step 7. Print the last elements of the data set.

# %%
stud_alco.tail()

# %% [markdown]
# ### Step 8. Did you notice the original dataframe is still lowercase? Why is that? Fix it and capitalize Mjob and Fjob.

# %%
df['Mjob'] = df['Mjob'].apply(capitalizer)
df['Fjob'] = df['Fjob'].apply(capitalizer)
df.head()

# %% [markdown]
# ### Step 9. Create a new column called legal_drinker values of the legal_drinker column (Consider cutsomer with more than 17 years old)

# %%
def majority(x):
    if x > 17:
        return True
    else:
        return False

df['legal_drinker'] = df['age'].apply(majority)
df.head()

# %% [markdown]
# ### Step 10. Multiply every number of the dataset by 10.
# ##### I know this makes no sense, don't forget it is just an exercise

# %%
def times10(x):
    if type(x) is int:
        return 10 * x
    return x

df = df.applymap(times10)
df.head()
